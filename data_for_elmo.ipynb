# %%
import pandas as pd

# %%
dt = pd.read_csv('train.csv')
# english data set
df_en = dt.loc[dt['lang_abv'] == 'en']
df_en
# Out:
#                id                                            premise  \
# 0      5130fd2cb5  and these comments were considered in formulat...
# 1      5b72532a0b  These are issues that we wrestle with in pract...
# 3      5622f0c60b  you know they can't really defend themselves l...
# 7      fdcd1bd867              From Cockpit Country to St. Ann's Bay
# 8      7cfb3d272c  Look, it's your skin, but you're going to be i...
# ...           ...                                                ...
# 12115  2b78e2a914  The results of even the most well designed epi...
# 12116  7e9943d152  But there are two kinds of  the pleasure of do...
# 12117  5085923e6c  The important thing is to realize that it's wa...
# 12118  fc8e2fd1fe  At the west end is a detailed model of the who...
# 12119  44301dfb14  For himself he chose Atat??rk, or Father of th...
#
#                                               hypothesis lang_abv language  \
# ...

# %%
df = pd.DataFrame()

# %%
df['label'] = df_en['label']
df['#1 ID']= df_en['id']
df['#2 ID']= df_en['id'] + '1'
df['text0'] = df_en['premise']
df['text1'] = df_en['hypothesis']

# %%
df
# Out:
#        label       #1 ID        #2 ID  \
# 0          0  5130fd2cb5  5130fd2cb51
# 1          2  5b72532a0b  5b72532a0b1
# 3          0  5622f0c60b  5622f0c60b1
# 7          2  fdcd1bd867  fdcd1bd8671
# 8          1  7cfb3d272c  7cfb3d272c1
# ...      ...         ...          ...
# 12115      2  2b78e2a914  2b78e2a9141
# 12116      0  7e9943d152  7e9943d1521
# 12117      2  5085923e6c  5085923e6c1
# 12118      2  fc8e2fd1fe  fc8e2fd1fe1
# 12119      0  44301dfb14  44301dfb141
#
#                                                    text0  \
# 0      and these comments were considered in formulat...
# 1      These are issues that we wrestle with in pract...
# 3      you know they can't really defend themselves l...
# 7                  From Cockpit Country to St. Ann's Bay
# 8      Look, it's your skin, but you're going to be i...
# ...                                                  ...
# 12115  The results of even the most well designed epi...
# ...

# %%
df.to_csv('example.tsv', sep="\t", index = False)
